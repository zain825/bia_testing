# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 653.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.0/11.6 MB 653.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.6 MB 409.6 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/11.6 MB 599.1 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/11.6 MB 566.5 kB/s eta 0:00:21
#     --------------------------------------- 0.2/11.6 MB 724.0 kB/s eta 0:00:16
#     --------------------------------------- 0.3/11.6 MB 785.2 kB/s eta 0:00:15
#     --------------------------------------- 0.3/11.6 MB 710.0 kB/s eta 0:00:16
#    - -------------------------------------- 0.3/11.6 MB 728.0 kB/s eta 0:00:16
#    - -------------------------------------- 0.4/11.6 MB 807.8 kB/s eta 0:00:14
#    - -------------------------------------- 0.4/11.6 MB 778.2 kB/s eta 0:00:15
# ...

# %%
import pandas as pd

# %%
pd.Series([1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
d = pd.DataFrame(data = {'studentname':['bilal','zain','nouman'],'studentmarks':[89,78,56]})

# %%
d
# Out:
#   studentname  studentmarks
# 0       bilal            89
# 1        zain            78
# 2      nouman            56

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Index',
#  'Customer Id',
#  'First Name',
#  'Last Name',
#  'Company',
#  'City',
#  'Country',
#  'Phone 1',
#  'Phone 2',
#  'Email',
#  'Subscription Date',
#  'Website']

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df[['Subscription Date','Website']]
# Out:
#    Subscription Date                            Website
# 0         2020-08-24         http://www.stephenson.com/
# 1         2021-04-23              http://www.hobbs.com/
# 2         2020-03-25           http://www.lawrence.com/
# 3         2020-06-02         http://www.good-lyons.com/
# 4         2021-04-17        https://goodwin-ingram.com/
# ..               ...                                ...
# 95        2022-01-30            http://hayes-perez.com/
# 96        2021-07-10         https://novak-allison.com/
# 97        2021-09-18              https://www.ross.com/
# 98        2021-08-11               http://watkins.info/
# 99        2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 2 columns]

# %%
df.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
#how to convert data type of a column
#gitscm(install)

# %%
df['Index'] = df['Index'].astype(str)

# %%
for i in df.columns:
    df[i] = df[i].astype(str)
    print(i)
# Out:
# Index
# Customer Id
# First Name
# Last Name
# Company
# City
# Country
# Phone 1
# Phone 2
# Email
# Subscription Date
# Website

# %%
for i in df.columns:
    if i == 'Company' or i =='Phone 1' or i =='Phone 2':
        df[i] = df[i].astype(str)
        print(i)
# Out:
# Company
# Phone 1
# Phone 2

# %%
df['Subscription Date'] = pd.to_datetime(df['Subscription Date'])

# %%
df1 = pd.read_csv('professors.csv')
df2 = pd.read_csv('students.csv')
merge_df = pd.merge(df1,df2,on = ['id_number'],how = 'inner')
merge_df
# Out:
#          Prof_name  id_number Department               Name  Age Gender
# 0     Thomas Smith        204        ECE        James Smith   26      M
# 1  Margaret Garcia        264         EE        David Smith   24      M
# 2   Richard Miller        238         ME  Jessica Hernandez   25      F
# 3   Margaret MOORE        136         CE    Patricia Garcia   21      F

# %%
#how to check null values in all columns
#forward filling
#backward filling
#github and gitcsm
#use the excel file and convert all the graphs in python(matplotlib,plotly,seaborn)
#what is inplace in pandas

# %%
df1 = df1.rename(columns={'id_number':'id'})
df2 = df2.rename(columns={'id_number':'id'})

# %%
df1
# Out:
#          Prof_name   id Department
# 0     Thomas Smith  204        ECE
# 1  Margaret Garcia  264         EE
# 2    James Johnson  108        CSE
# 3   Richard Miller  238         ME
# 4   Margaret MOORE  136         CE

# %%
import numpy as np

# %%
df2['id'] = np.where(df2['id'] == 238,500,df2['id'])

# %%
df2
# Out:
#     id               Name  Age Gender
# 0  204        James Smith   26      M
# 1  202    Maria Rodriguez   22      F
# 2  264        David Smith   24      M
# 3  136    Patricia Garcia   21      F
# 4  500  Jessica Hernandez   25      F

# %%
#data normalization
#how to insert data using python in a database
